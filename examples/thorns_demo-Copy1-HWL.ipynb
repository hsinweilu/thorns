# %% [markdown]
# # This is for HWL's practice

# %%
# %matplotlib inline

# %%
from __future__ import division, print_function, absolute_import

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import thorns as th
import thorns.waves as wv
from thorns.datasets import load_anf_zilany2014

# %% [markdown]
# ## Waves Demo
#
# Note: errors generated here.
#
# I have to make sure the arguments in `np.linspace` to be `integer` in the `thorns/waves.py` file.

# %%
sound = wv.amplitude_modulated_tone(
    fs=48e3,
    fm=100,
    fc=1e3,
    m=0.7,
    duration=0.1,
)

wv.plot_signal(sound, fs=48e3)

# %% [markdown]
# ## Thorns Demo
#
# NOTE: Can't load `anf_zilany2014.pkl` file. Somehow the pd.read_pickle just can't read the file!
#
# See following

# %%
# Error generated
pd.read_pickle('../thorns/datasets/anf_zilany2014.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5c1efdbbdd50> in <module>
#       1 # Error generated
# ----> 2 pd.read_pickle('../thorns/datasets/anf_zilany2014.pkl')
#
# ~/pyvenv/cnmodel/lib/python3.8/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     180                 # We want to silence any warnings about, e.g. moved modules.
#     181                 warnings.simplefilter("ignore", Warning)
# --> 182                 return pickle.load(f)
#     183         except excs_to_catch:
#     184             # e.g.
#
# TypeError: _reconstruct: First argument must be a sub-type of ndarray

# %%
# ?pd.read_pickle

# %%
spike_trains = load_anf_zilany2014()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f81185438c84> in <module>
# ----> 1 spike_trains = load_anf_zilany2014()
#
# ~/Documents/python/thorns/thorns/datasets/__init__.py in load_anf_zilany2014()
#      31     module_path = dirname(__file__)
#      32
# ---> 33     spike_trains = pd.read_pickle(
#      34         join(module_path, "anf_zilany2014.pkl")
#      35     )
#
# ~/pyvenv/cnmodel/lib/python3.8/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     180                 # We want to silence any warnings about, e.g. moved modules.
#     181                 warnings.simplefilter("ignore", Warning)
# --> 182                 return pickle.load(f)
#     183         except excs_to_catch:
#     184             # e.g.
#
# TypeError: _reconstruct: First argument must be a sub-type of ndarray

# %%
th.plot_raster(spike_trains)

# %%
# ?th.plot_raster
